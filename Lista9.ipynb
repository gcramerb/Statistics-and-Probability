# %% [markdown]
# ### Lista 9:
# #### Guilherme Cramer Barbosa Silva
# ###### 2015102170
# Fazer os exercícios 1 e 2 do Capítulo 8 (PCA)

# %%
# exercicios 1 
from tensorflow.keras.datasets import mnist
from sklearn.decomposition import PCA
from sklearn.neighbors import KNeighborsClassifier as KNN
from sklearn.metrics import confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
(X_train, Y_train), (X_test, Y_test) = mnist.load_data()
X_train = X_train.reshape(len(X_train),28*28)
X_test = X_test.reshape(len(X_test),28*28)

# %%
k = 5
knn = KNN(n_neighbors=8)
pca = PCA(n_components=k)
X_train_new = pca.fit_transform(X_train)
X_test_new = pca.transform(X_test)
knn.fit(X = X_train_new,y = Y_train)
y_hat = knn.predict(X_test_new)
cm = confusion_matrix(Y_test,y_hat)
cm_list.append(cm)
sns.heatmap(cm, annot=True,fmt="d")
plt.title(f'K = {k}')
np.mean(np.diag(cm))
pm = 0.1*np.sum(np.diag(cm) / np.sum(cm,axis = 1))
rm = 0.1*np.sum(np.diag(cm) / np.sum(cm,axis = 0))
print(f'result = {np.mean(np.diag(cm))}')
print(f"rm : {rm}")
print(f'pm : {pm}')
# Out:
# result = 758.2
# rm : 0.9690918588738962
# pm : 0.9687532047155575

# %%
k = 10
knn = KNN(n_neighbors=8)
pca = PCA(n_components=k)
X_train_new = pca.fit_transform(X_train)
X_test_new = pca.transform(X_test)
knn.fit(X = X_train_new,y = Y_train)
y_hat = knn.predict(X_test_new)
cm = confusion_matrix(Y_test,y_hat)
cm_list.append(cm)
sns.heatmap(cm, annot=True,fmt="d")
plt.title(f'K = {k}')
np.mean(np.diag(cm))
pm = 0.1*np.sum(np.diag(cm) / np.sum(cm,axis = 1))
rm = 0.1*np.sum(np.diag(cm) / np.sum(cm,axis = 0))
print(f'result = {np.mean(np.diag(cm))}')
print(f"rm : {rm}")
print(f'pm : {pm}')
# Out:
# result = 929.1
# rm : 0.9690918588738962
# pm : 0.9687532047155575

# %%
k = 15
knn = KNN(n_neighbors=8)
pca = PCA(n_components=k)
X_train_new = pca.fit_transform(X_train)
X_test_new = pca.transform(X_test)
knn.fit(X = X_train_new,y = Y_train)
y_hat = knn.predict(X_test_new)
cm = confusion_matrix(Y_test,y_hat)
sns.heatmap(cm, annot=True,fmt="d")
plt.title(f'K = {k}')
np.mean(np.diag(cm))
pm = 0.1*np.sum(np.diag(cm) / np.sum(cm,axis = 1))
rm = 0.1*np.sum(np.diag(cm) / np.sum(cm,axis = 0))
print(f'result = {np.mean(np.diag(cm))}')
print(f"rm : {rm}")
print(f'pm : {pm}')
# Out:
# result = 959.8
# rm : 0.9690918588738962
# pm : 0.9687532047155575

# %%
k = 20
knn = KNN(n_neighbors=8)
pca = PCA(n_components=k)
X_train_new = pca.fit_transform(X_train)
X_test_new = pca.transform(X_test)
knn.fit(X = X_train_new,y = Y_train)
y_hat = knn.predict(X_test_new)
cm = confusion_matrix(Y_test,y_hat)
sns.heatmap(cm, annot=True,fmt="d")
plt.title(f'K = {k}')
pm = 0.1*np.sum(np.diag(cm) / np.sum(cm,axis = 1))
rm = 0.1*np.sum(np.diag(cm) / np.sum(cm,axis = 0))

print(f'result = {np.mean(np.diag(cm))}')
print(f"rm : {rm}")
print(f'pm : {pm}')
# Out:
# result = 969.0
# rm : 0.9690918588738962
# pm : 0.9687532047155575

# %%
# questao 2
x = np.random.normal(0,1,1000)
y = np.random.normal(0,1,1000)
z = 3 + 1.2*x -1.2*y +np.random.normal(0,0.3,1000)
data = np.array([x,y,z]).reshape(1000,3)
df = pd.DataFrame(data)


import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
sigma = np.cov(data.reshape(3,1000))
np.linalg.eig(sigma)
# Out:
# (array([3.79313697, 0.95952847, 0.02232891]),
#  array([[-0.37148146,  0.69451324, -0.61615978],
#         [ 0.33460829,  0.71920101,  0.60892298],
#         [-0.86604781, -0.02003143,  0.49955973]]))

# %%
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.scatter3D(x, y, z, c=z, cmap='hsv');
plt.show()

# %%
trees = pd.read_csv('trees.csv',index_col = 0)
x = np.log(trees)
fig = plt.figure()
ax = plt.axes(projection="3d")
ax.scatter3D(x.iloc[:,0], x.iloc[:,1], x.iloc[:,2], c=x.iloc[:,2], cmap='hsv');
plt.show()
